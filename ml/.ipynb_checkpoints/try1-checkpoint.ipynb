# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('AAPL.csv')
df.head(6)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2020-04-21  69.070000  69.312500  66.357498  67.092499  66.576424
# 1  2020-04-22  68.402496  69.474998  68.050003  69.025002  68.494064
# 2  2020-04-23  68.967499  70.437500  68.717499  68.757500  68.228622
# 3  2020-04-24  69.300003  70.752502  69.250000  70.742500  70.198349
# 4  2020-04-27  70.449997  71.135002  69.987503  70.792503  70.247971
# 5  2020-04-28  71.269997  71.457497  69.550003  69.644997  69.109299
#
#       Volume
# 0  180991600
# 1  117057200
# 2  124814400
# 3  126508800
# 4  117087600
# 5  112004800

# %%
plt.figure(figsize=(16,8))
plt.title('AAPL', fontsize = 18)
plt.xlabel('Days', fontsize= 18)
plt.ylabel('Close Price USD ($)', fontsize = 18)
plt.plot(df['Close'])
plt.show()

# %%
df = df[['Close']]
df.head(6)
# Out:
#        Close
# 0  67.092499
# 1  69.025002
# 2  68.757500
# 3  70.742500
# 4  70.792503
# 5  69.644997

# %%
predict_days = 30
df['Prediction'] = df[['Close']].shift(-predict_days)
df.tail(4)
# Out:
#           Close  Prediction
# 248  134.500000         NaN
# 249  134.160004         NaN
# 250  134.839996         NaN
# 251  133.110001         NaN

# %%
x = np.array(df.drop(['Prediction'], 1))[:-predict_days]
# print(x)
y = np.array(df['Prediction'])[:-predict_days]
# print(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25)
